# %%
import matplotlib.pyplot as plt  # https://matplotlib.org/api/pyplot_summary.html
import pandas as pd  # https://pandas.pydata.org/pandas-docs/stable/
import seaborn as sns  # https://seaborn.pydata.org/api.html
# %matplotlib inline

# %%
print('Read the assignment-01/Batting.csv from github into Pandas DataFrame called df.')
df = pd.read_csv('https://raw.githubusercontent.com/chirayukong/infsci2725-spring-2018/master/assignment-01/Batting.csv')
# Out:
# Read the assignment-01/Batting.csv from github into Pandas DataFrame called df.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96183 entries, 0 to 96182
# Data columns (total 11 columns):
# playerID        96183 non-null object
# yearID          96183 non-null int64
# teamID          96183 non-null object
# Games           96183 non-null int64
# Atbats          96183 non-null int64
# RunsScored      96183 non-null int64
# Hits            96183 non-null int64
# Homeruns        96183 non-null int64
# RunsBattedIn    96183 non-null int64
# Walks           96183 non-null int64
# strikeOuts      96183 non-null int64
# dtypes: int64(9), object(2)
# memory usage: 8.1+ MB

# %%
df.head()
# Out:
#     playerID  yearID teamID  Games  Atbats  RunsScored  Hits  Homeruns  \
# 0  kigerma01    2006    OAK      0       0           0     0         0
# 1    joyce01    1886    WS8      1       0           0     0         0
# 2  flynnjo02    1887    CHN      1       0           0     0         0
# 3  banniji01    1888    WS8      1       0           0     0         0
# 4  conovte01    1889    CN2      1       0           0     0         0
#
#    RunsBattedIn  Walks  strikeOuts
# 0             0      0           0
# 1             0      0           0
# 2             0      0           0
# 3             0      0           0
# 4             0      0           0

# %%
df.describe(include='all')
# Out:
#          playerID        yearID teamID         Games        Atbats  \
# count       96183  96183.000000  96183  96183.000000  96183.000000
# unique      18232           NaN    149           NaN           NaN
# top     mcguide01           NaN    CHN           NaN           NaN
# freq           31           NaN   4818           NaN           NaN
# mean          NaN   1962.271888    NaN     52.999823    149.970327
# std           NaN     39.233078    NaN     47.716644    186.557072
# min           NaN   1871.000000    NaN      0.000000      0.000000
# 25%           NaN   1931.000000    NaN     13.000000      7.000000
# 50%           NaN   1969.000000    NaN     36.000000     57.000000
# 75%           NaN   1998.000000    NaN     85.000000    251.000000
# max           NaN   2015.000000    NaN    165.000000    716.000000
#
#           RunsScored          Hits      Homeruns  RunsBattedIn         Walks  \
# count   96183.000000  96183.000000  96183.000000  96183.000000  96183.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       19.887038     39.261647      2.949305     17.885967     13.811484
# std        28.671365     53.310941      6.409662     26.723989     21.092775
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.000000      1.000000      0.000000      0.000000      0.000000
# 50%         5.000000     11.000000      0.000000      4.000000      3.000000
# 75%        30.000000     63.000000      3.000000     26.000000     20.000000
# max       192.000000    262.000000     73.000000    191.000000    232.000000
#
#           strikeOuts
# count   96183.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean       19.867222
# std        27.884991
# min         0.000000
# 25%         1.000000
# 50%         8.000000
# 75%        28.000000
# max       223.000000

# %%
figsize = (10, 10)
print('Save default figure size and change figure size to', figsize)
default_figsize = plt.rcParams["figure.figsize"]
plt.rcParams["figure.figsize"] = figsize
# Out:
# Save default figure size and change figure size to (10, 10)

# %%
print('Filter df where teamID = OAK, yearID = 2010 and Homeruns > 0 into oak2010_df.')
oak2010_df = df[(df.teamID == 'OAK') & (df.yearID == 2010) & (df.Homeruns > 0)]
# Out:
# Filter df where teamID = OAK, yearID = 2010 and Homeruns > 0 into oak2010_df.

# %%
print('Plot oak2010_df Homeruns as a (vertical) bar chart.')
_ = oak2010_df.plot.bar(y='Homeruns')
# Out:
# Plot oak2010_df Homeruns as a (vertical) bar chart.

# %% [markdown]
# # Question 1
# ### Improve the previous bar chart:
#
#     as a horizontal bar chart.
#     label player bars with their playerID (not their index ID as in the chart above).
#     use only ONE color for all bars.
#     filter out all bar with hight of 0.
#     (extra points) sort by the number of Homeruns.

# %%
print('Plot oak2010_df Homeruns as a (Horizontal with additional features) bar chart.')
_ = oak2010_df.sort_values(ascending=False, by='Homeruns').plot.barh(y='Homeruns', color='y' )
# Out:
# Plot oak2010_df Homeruns as a (Horizontal with additional features) bar chart.

# %%
print('Plot oak2010_df as a (vertical,) stacked bar chart.')
_ = oak2010_df.plot.bar(stacked=True)
# Out:
# Plot oak2010_df as a (vertical,) stacked bar chart.

# %% [markdown]
# # Question 2
# ### Improve the previous stacked bar chart:
#
#     as a horizontal, stacked bar chart.
#     stack only Homeruns and RunsScored.
#     label player bars with their playerID (not their index ID as in the chart above).
#     filter out bars with hight of 0.
#     (extra points) sort by the number of RunsScored.

# %%
print('Plot oak2010_df as a (Horizontal,) stacked bar chart with additional features required in the question.')
_ = oak2010_df.sort_values(ascending=False, by='RunsScored').plot.barh(stacked=True, x='playerID', y=['Homeruns', 'RunsScored'])
# Out:
# Plot oak2010_df as a (Horizontal,) stacked bar chart with additional features required in the question.

# %%
print('Sum df Homeruns by yearID against teamID where yearID > 2000 into team_homeruns_per_year_df and fill N/A with 0.0.')
team_homeruns_per_year_df = df[df.yearID > 2000].pivot_table(values='Homeruns', index='yearID', columns='teamID', aggfunc='sum', fill_value=0.0)
team_homeruns_per_year_df.head()
# Out:
# Sum df Homeruns by yearID against teamID where yearID > 2000 into team_homeruns_per_year_df and fill N/A with 0.0.
# teamID  ANA  ARI  ATL  BAL  BOS  CHA  CHN  CIN  CLE  COL ...   PHI  PIT  SDN  \
# yearID                                                   ...
# 2001    158  208  174  136  198  214  194  176  212  213 ...   164  161  161
# 2002    152  165  164  165  177  217  200  169  192  152 ...   165  142  136
# 2003    150  152  235  152  238  220  172  182  158  198 ...   166  163  128
# 2004    162  135  178  169  222  242  235  194  184  202 ...   215  142  139
# 2005      0  191  184  189  199  200  194  222  207  150 ...   167  139  130
#
# teamID  SEA  SFN  SLN  TBA  TEX  TOR  WAS
# yearID
# 2001    169  235  199  121  246  195    0
# 2002    152  198  175  133  230  187    0
# 2003    139  180  196  137  239  190    0
# 2004    136  183  214  145  227  145    0
# 2005    130  128  170  157  260  136  117
#
# [5 rows x 33 columns]

# %%
print('Plot team_homeruns_per_year_df as an area chart.')
_ = team_homeruns_per_year_df.plot.area()
# Out:
# Plot team_homeruns_per_year_df as an area chart.

# %%
team_homeruns_per_year_df.head()
# Out:
# teamID  ANA  ARI  ATL  BAL  BOS  CHA  CHN  CIN  CLE  COL ...   PHI  PIT  SDN  \
# yearID                                                   ...
# 2001    158  208  174  136  198  214  194  176  212  213 ...   164  161  161
# 2002    152  165  164  165  177  217  200  169  192  152 ...   165  142  136
# 2003    150  152  235  152  238  220  172  182  158  198 ...   166  163  128
# 2004    162  135  178  169  222  242  235  194  184  202 ...   215  142  139
# 2005      0  191  184  189  199  200  194  222  207  150 ...   167  139  130
#
# teamID  SEA  SFN  SLN  TBA  TEX  TOR  WAS
# yearID
# 2001    169  235  199  121  246  195    0
# 2002    152  198  175  133  230  187    0
# 2003    139  180  196  137  239  190    0
# 2004    136  183  214  145  227  145    0
# 2005    130  128  170  157  260  136  117
#
# [5 rows x 33 columns]

# %% [markdown]
# # Question 3
# ### Improve the previous area chart:
#
#     including only the first 5 teams sorted by the highest number of home runs in any year [2001 - 2015]:
#     including only the first 5 teams sorted by the average number of home runs over the years [2001 - 2015]:

# %%
import numpy as np
print("including only the first 5 teams sorted by the highest number of home runs in any year [2001 - 2015]: ")
print('Plot team_homeruns_per_year_df as an area chart.')
#df=[df.teamID for i in np.argsort(df.Homerums)[-5:]]
#df = df.sort_values(ascending=False, by='Homeruns')
#_ = df.teamID for i in np.argsort(df.Homerums[i])[-5:])

team_homeruns_per_year_df = df[(df.yearID > 2000) & (df.yearID < 2016)].pivot_table(values='Homeruns', index='yearID', columns='teamID', aggfunc= 'sum', fill_value=0.0)

team_homeruns_per_year_df1 = df[(df.yearID > 2000) & (df.yearID < 2016)].pivot_table(values='Homeruns', index='teamID', columns='yearID', aggfunc= 'sum', fill_value=0.0)

sorted_data = team_homeruns_per_year_df1. apply(lambda x:x.sort_values(ascending = False).values)
#team_homeruns_per_year_df = team_homeruns_per_year_df[groupby(team_homeruns_per_year_df.Homeruns)]
#team_homeruns_per_year_df.sort_values(ascending=False, by='yearID',)[:5]
#team_homeruns_per_year_df = team_homeruns_per_year_df.nlargest(5, 'teamID')
# Out:
# including only the first 5 teams sorted by the highest number of home runs in any year [2001 - 2015]:
# Plot team_homeruns_per_year_df as an area chart.

# %%
team_homeruns_per_year_df.head()
# Out:
# teamID  ANA  ARI  ATL  BAL  BOS  CHA  CHN  CIN  CLE  COL ...   PHI  PIT  SDN  \
# yearID                                                   ...
# 2001    158  208  174  136  198  214  194  176  212  213 ...   164  161  161
# 2002    152  165  164  165  177  217  200  169  192  152 ...   165  142  136
# 2003    150  152  235  152  238  220  172  182  158  198 ...   166  163  128
# 2004    162  135  178  169  222  242  235  194  184  202 ...   215  142  139
# 2005      0  191  184  189  199  200  194  222  207  150 ...   167  139  130
#
# teamID  SEA  SFN  SLN  TBA  TEX  TOR  WAS
# yearID
# 2001    169  235  199  121  246  195    0
# 2002    152  198  175  133  230  187    0
# 2003    139  180  196  137  239  190    0
# 2004    136  183  214  145  227  145    0
# 2005    130  128  170  157  260  136  117
#
# [5 rows x 33 columns]

# %%
sorted_data.head()
# Out:
# yearID  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# teamID
# ANA      246   230   239   242   260   236   231   235   244   257   222
# ARI      235   223   238   242   229   222   213   214   224   211   210
# ATL      214   217   235   235   222   217   204   208   224   201   203
# BAL      213   205   230   227   207   216   201   200   212   188   191
# BOS      212   200   220   222   200   210   201   198   209   182   186
#
# yearID  2012  2013  2014  2015
# teamID
# ANA      245   212   211   232
# ARI      214   188   186   230
# ATL      211   186   177   217
# BAL      202   185   163   212
# BOS      200   181   157   198

# %%
best_teams = ['ANA', 'ARI', 'ATL', 'BAL', 'BOS']
_ = team_homeruns_per_year_df[best_teams].plot.area()

# %%
for year, team in team_homeruns_per_year_df.iterrows():
    df2 = pd.DataFrame(team)
    print(df2)
# Out:
#         2001
# teamID
# ANA      158
# ARI      208
# ATL      174
# BAL      136
# BOS      198
# CHA      214
# CHN      194
# CIN      176
# CLE      212
# COL      213
# DET      139
# FLO      166
# HOU      208
# KCA      152
# LAA        0
# LAN      206
# MIA        0
# MIL      209
# MIN      164
# MON      131
# NYA      203
# NYN      147
# OAK      199
# PHI      164
# PIT      161
# SDN      161
# SEA      169
# SFN      235
# SLN      199
# TBA      121
# TEX      246
# TOR      195
# WAS        0
#         2002
# teamID
# ANA      152
# ARI      165
# ATL      164
# BAL      165
# BOS      177
# CHA      217
# CHN      200
# CIN      169
# CLE      192
# COL      152
# DET      124
# FLO      146
# HOU      167
# KCA      140
# LAA        0
# LAN      155
# MIA        0
# MIL      139
# MIN      167
# MON      162
# NYA      223
# NYN      160
# OAK      205
# PHI      165
# PIT      142
# SDN      136
# SEA      152
# SFN      198
# SLN      175
# TBA      133
# TEX      230
# TOR      187
# WAS        0
#         2003
# teamID
# ANA      150
# ARI      152
# ATL      235
# BAL      152
# BOS      238
# CHA      220
# CHN      172
# CIN      182
# CLE      158
# COL      198
# DET      153
# FLO      157
# HOU      191
# KCA      162
# LAA        0
# LAN      124
# MIA        0
# MIL      196
# MIN      155
# MON      144
# NYA      230
# NYN      124
# OAK      176
# PHI      166
# PIT      163
# SDN      128
# SEA      139
# SFN      180
# SLN      196
# TBA      137
# TEX      239
# TOR      190
# WAS        0
#         2004
# teamID
# ANA      162
# ARI      135
# ATL      178
# BAL      169
# BOS      222
# CHA      242
# CHN      235
# CIN      194
# CLE      184
# COL      202
# DET      201
# FLO      148
# HOU      187
# KCA      150
# LAA        0
# LAN      203
# MIA        0
# MIL      135
# MIN      191
# MON      151
# NYA      242
# NYN      185
# OAK      189
# PHI      215
# PIT      142
# SDN      139
# SEA      136
# SFN      183
# SLN      214
# TBA      145
# TEX      227
# TOR      145
# WAS        0
#         2005
# teamID
# ANA        0
# ARI      191
# ATL      184
# BAL      189
# BOS      199
# CHA      200
# CHN      194
# CIN      222
# CLE      207
# COL      150
# DET      168
# FLO      128
# HOU      161
# KCA      126
# LAA      147
# LAN      149
# MIA        0
# MIL      175
# MIN      134
# MON        0
# NYA      229
# NYN      175
# OAK      155
# PHI      167
# PIT      139
# SDN      130
# SEA      130
# SFN      128
# SLN      170
# TBA      157
# TEX      260
# TOR      136
# WAS      117
#         2006
# teamID
# ANA        0
# ARI      160
# ATL      222
# BAL      164
# BOS      192
# CHA      236
# CHN      166
# CIN      217
# CLE      196
# COL      157
# DET      203
# FLO      182
# HOU      174
# KCA      124
# LAA      159
# LAN      153
# MIA        0
# MIL      180
# MIN      143
# MON        0
# NYA      210
# NYN      200
# OAK      175
# PHI      216
# PIT      141
# SDN      161
# SEA      172
# SFN      163
# SLN      184
# TBA      190
# TEX      183
# TOR      199
# WAS      164
#         2007
# teamID
# ANA        0
# ARI      171
# ATL      176
# BAL      142
# BOS      166
# CHA      190
# CHN      151
# CIN      204
# CLE      178
# COL      171
# DET      177
# FLO      201
# HOU      167
# KCA      102
# LAA      123
# LAN      129
# MIA        0
# MIL      231
# MIN      118
# MON        0
# NYA      201
# NYN      177
# OAK      171
# PHI      213
# PIT      148
# SDN      171
# SEA      153
# SFN      131
# SLN      141
# TBA      187
# TEX      179
# TOR      165
# WAS      123
#         2008
# teamID
# ANA        0
# ARI      159
# ATL      130
# BAL      172
# BOS      173
# CHA      235
# CHN      184
# CIN      187
# CLE      171
# COL      160
# DET      200
# FLO      208
# HOU      167
# KCA      120
# LAA      159
# LAN      137
# MIA        0
# MIL      198
# MIN      111
# MON        0
# NYA      180
# NYN      172
# OAK      125
# PHI      214
# PIT      153
# SDN      154
# SEA      124
# SFN       94
# SLN      174
# TBA      180
# TEX      194
# TOR      126
# WAS      117
#         2009
# teamID
# ANA        0
# ARI      173
# ATL      149
# BAL      160
# BOS      212
# CHA      184
# CHN      161
# CIN      158
# CLE      161
# COL      190
# DET      183
# FLO      159
# HOU      142
# KCA      144
# LAA      173
# LAN      145
# MIA        0
# MIL      182
# MIN      172
# MON        0
# NYA      244
# NYN       95
# OAK      135
# PHI      224
# PIT      125
# SDN      141
# SEA      160
# SFN      122
# SLN      160
# TBA      199
# TEX      224
# TOR      209
# WAS      156
#         2010
# teamID
# ANA        0
# ARI      180
# ATL      139
# BAL      133
# BOS      211
# CHA      177
# CHN      149
# CIN      188
# CLE      128
# COL      173
# DET      152
# FLO      152
# HOU      108
# KCA      121
# LAA      155
# LAN      120
# MIA        0
# MIL      182
# MIN      142
# MON        0
# NYA      201
# NYN      128
# OAK      109
# PHI      166
# PIT      126
# SDN      132
# SEA      101
# SFN      162
# SLN      150
# TBA      160
# TEX      162
# TOR      257
# WAS      149
#         2011
# teamID
# ANA        0
# ARI      172
# ATL      173
# BAL      191
# BOS      203
# CHA      154
# CHN      148
# CIN      183
# CLE      154
# COL      163
# DET      169
# FLO      149
# HOU       95
# KCA      129
# LAA      155
# LAN      117
# MIA        0
# MIL      185
# MIN      103
# MON        0
# NYA      222
# NYN      108
# OAK      114
# PHI      153
# PIT      107
# SDN       91
# SEA      109
# SFN      121
# SLN      162
# TBA      172
# TEX      210
# TOR      186
# WAS      154
#         2012
# teamID
# ANA        0
# ARI      165
# ATL      149
# BAL      214
# BOS      165
# CHA      211
# CHN      137
# CIN      172
# CLE      136
# COL      166
# DET      163
# FLO        0
# HOU      146
# KCA      131
# LAA      187
# LAN      116
# MIA      137
# MIL      202
# MIN      131
# MON        0
# NYA      245
# NYN      139
# OAK      195
# PHI      158
# PIT      170
# SDN      121
# SEA      149
# SFN      103
# SLN      159
# TBA      175
# TEX      200
# TOR      198
# WAS      194
#         2013
# teamID
# ANA        0
# ARI      130
# ATL      181
# BAL      212
# BOS      178
# CHA      148
# CHN      172
# CIN      155
# CLE      171
# COL      159
# DET      176
# FLO        0
# HOU      148
# KCA      112
# LAA      164
# LAN      138
# MIA       95
# MIL      157
# MIN      151
# MON        0
# NYA      144
# NYN      130
# OAK      186
# PHI      140
# PIT      161
# SDN      146
# SEA      188
# SFN      107
# SLN      125
# TBA      165
# TEX      176
# TOR      185
# WAS      161
#         2014
# teamID
# ANA        0
# ARI      118
# ATL      123
# BAL      211
# BOS      123
# CHA      155
# CHN      157
# CIN      131
# CLE      142
# COL      186
# DET      155
# FLO        0
# HOU      163
# KCA       95
# LAA      155
# LAN      134
# MIA      122
# MIL      150
# MIN      128
# MON        0
# NYA      147
# NYN      125
# OAK      146
# PHI      125
# PIT      156
# SDN      109
# SEA      136
# SFN      132
# SLN      105
# TBA      117
# TEX      111
# TOR      177
# WAS      152
#         2015
# teamID
# ANA        0
# ARI      154
# ATL      100
# BAL      217
# BOS      161
# CHA      136
# CHN      171
# CIN      167
# CLE      141
# COL      186
# DET      151
# FLO        0
# HOU      230
# KCA      139
# LAA      176
# LAN      187
# MIA      120
# MIL      145
# MIN      156
# MON        0
# NYA      212
# NYN      177
# OAK      146
# PHI      130
# PIT      140
# SDN      148
# SEA      198
# SFN      136
# SLN      137
# TBA      167
# TEX      172
# TOR      232
# WAS      177

# %%
print("including only the first 5 teams sorted by the average number of home runs over the years [2001 - 2015]:")

print('Plot team_homeruns_per_year_df as an area chart.')
team_homeruns_per_year_df = df[(df.yearID > 2000) & (df.yearID < 2016)].pivot_table(values='Homeruns', index='yearID', columns='teamID', aggfunc = 'mean', fill_value=0.0) 
team_homeruns_per_year_df.head()
sorted_data = team_homeruns_per_year_df1. apply(lambda x:x.sort_values(ascending = False).values)
sorted_data.head()
best_teams = ['ANA', 'ARI', 'ATL', 'BAL', 'BOS']
_ = team_homeruns_per_year_df[best_teams].plot.area()
# Out:
# including only the first 5 teams sorted by the average number of home runs over the years [2001 - 2015]:
# Plot team_homeruns_per_year_df as an area chart.

# %%
print("Reset ")
plt.rcParams["figure.figsize"] = default_figsize
# Out:
# Reset

# %%
print("Plot df Homeruns by year from 2011 as a box chart.")
_ = df[df.yearID>2010].boxplot('Homeruns', 'yearID')
# Out:
# Plot df Homeruns by year from 2011 as a box chart.
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# #  Question 4
# ### Improve the previous box chart:
#
#     filter out records with Homeruns of 0.

# %%
print("Plot df Homeruns by year from 2011 as a box chart.")
_ = df[(df.yearID>2010) & (df.Homeruns > 0)].boxplot('Homeruns', 'yearID')
# Out:
# Plot df Homeruns by year from 2011 as a box chart.
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
print("Plot df Homeruns by year from 2011 as a violin chart.")
_ = sns.violinplot(y='Homeruns', x='yearID', data=df[df.yearID>2010])
# Out:
# Plot df Homeruns by year from 2011 as a violin chart.

# %% [markdown]
# # Question 5
# ### Improve the previous violin chart:
#
#     filter out records with Homeruns of 0.
#     use only ONE color for all violins.

# %%
print("Plot df Homeruns by year from 2011 as a violin chart.")
_ = sns.violinplot(y='Homeruns', x='yearID', data=df[(df.yearID>2010) & (df.Homeruns>0)], color='y')
# Out:
# Plot df Homeruns by year from 2011 as a violin chart.

# %%
print("Plot df Homeruns vs Walks for OAK as a Hex joint chart.")
oak_year_df = df[(df.teamID == 'OAK')].pivot_table(index='yearID', aggfunc='sum')
_ = sns.jointplot(data=oak_year_df, x='Walks', y='Homeruns', kind='hex')
# Out:
# Plot df Homeruns vs Walks for OAK as a Hex joint chart.

# %% [markdown]
# # Question 6
# ### Improve the previous joint chart to be kernel density estimation (KDE) joint chart for:
#
#     Homeruns vs strikeOuts for NYA
#     Homeruns vs strikeOuts for BOS

# %%
print("Plot df Homeruns vs strikeOuts for NYA as a Hex joint chart.")
oak_year_df = df[(df.teamID == 'NYA')].pivot_table(index='yearID', aggfunc='sum')
_ = sns.jointplot(data=oak_year_df, x='strikeOuts', y='Homeruns', kind='hex')
# Out:
# Plot df Homeruns vs strikeOuts for NYA as a Hex joint chart.

# %%
print("Plot df Homeruns vs strikeOuts for BOS as a Hex joint chart.")
oak_year_df = df[(df.teamID == 'BOS')].pivot_table(index='yearID', aggfunc='sum')
_ = sns.jointplot(data=oak_year_df, x='strikeOuts', y='Homeruns', kind='hex')
# Out:
# Plot df Homeruns vs strikeOuts for BOS as a Hex joint chart.
